# %%
# Import required libraries
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Evaluation function (GLOBAL scope)
def evaluate_model(model, X_test, y_test):
 y_pred = model.predict(X_test)
 y_pred_classes = np.argmax(y_pred, axis=1)
 print("\nClassification Report:\n")
 print(classification_report(y_test, y_pred_classes))
 print("\nConfusion Matrix:\n")
 print(confusion_matrix(y_test, y_pred_classes))

# %%
# Main function
def main():

 # Step 1: Load and preprocess dataset
 fashion_mnist = tf.keras.datasets.fashion_mnist
 (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
 X_train = X_train / 255.0
 X_test = X_test / 255.0

 # Reshape for CNN
 X_train = X_train.reshape(-1, 28, 28, 1)
 X_test = X_test.reshape(-1, 28, 28, 1)

 # Step 2: Build CNN model
 model = tf.keras.Sequential(
 [
 tf.keras.layers.Conv2D(
 32, (3, 3), activation="relu", input_shape=(28, 28, 1)
 ),
 tf.keras.layers.MaxPooling2D((2, 2)),
 tf.keras.layers.Flatten(),
 tf.keras.layers.Dense(10, activation="softmax"),
 ]
 )

# Step 3: Compile and train
 X_train, X_val, y_train, y_val = train_test_split(
 X_train, y_train, test_size=0.1, random_state=42
 )
 model.compile(
 optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
 )
 model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=5)
 return model, X_test, y_test

# %%
# Run everything
if __name__ == "__main__":
  model, X_test, y_test = main()
  evaluate_model(model, X_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 27s 16ms/step - accuracy: 0.7821 - loss: 0.6209 - val_accuracy: 0.8778 - val_loss: 0.3503
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.8862 - loss: 0.3206 - val_accuracy: 0.8960 - val_loss: 0.2926
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.9021 - loss: 0.2799 - val_accuracy: 0.8987 - val_loss: 0.2810
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - accuracy: 0.9083 - loss: 0.2582 - val_accuracy: 0.9008 - val_loss: 0.2745
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.9155 - loss: 0.2349 - val_accuracy: 0.9045 - val_loss: 0.2689
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85      1000
#            1       0.99      0.98      0.98      1000
#            2       0.82      0.85      0.83      1000
#            3       0.88      0.91      0.89      1000
#            4       0.81      0.90      0.85      1000
#            5       0.99      0.96      0.97      1000
#            6       0.79      0.63      0.70      1000
#            7       0.94      0.98      0.96      1000
#            8       0.97      0.98      0.97      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
#
# Confusion Matrix:
#
# [[854   0  26  38   7   1  64   0  10   0]
#  [  0 978   1  14   4   0   1   0   2   0]
#  [ 13   1 846  10  83   0  45   0   2   0]
#  [ 11   8  14 913  29   0  21   0   4   0]
#  [  1   0  44  26 897   0  31   0   1   0]
#  [  0   0   0   1   0 962   0  21   2  14]
#  [139   2  95  35  90   0 629   0  10   0]
#  [  0   0   0   0   0   6   0 978   1  15]
#  [  1   2   2   5   2   1   2   4 981   0]
#  [  0   0   0   0   0   4   0  40   1 955]]
